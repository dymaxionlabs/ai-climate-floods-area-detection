# %%
#!pip install -U unetseg

# %%
#!pip install tensorflow-estimator==2.7.0
#!pip install opencv-python==4.5.4.60

# %%
#!pip install git+https://github.com/dymaxionlabs/satproc.git@dab1cdbef0ef3a83c9e100952d9632e17bb18619

# %% [markdown]
# # Flood area detection
#
# ## 1_ Entrenamiento
#
#    El modelo de ML utiliza para entrenar un dataset compuesto por imágenes y máscaras para el entrenamiento. Estas ultimas son imagenes binarias que delimitan el objeto de interés, 1 donde esta y 0 donde no.

# %%
YEAR = "2020"
ZONA = "TEGUCIGALPA"

BUCKET = f"gs://dym-quilmes-trucks-temp/I2UD/floods/{ZONA.lower()}/imagenes/dataset_*tif" 
#General




###########
## SULA 
###########
N_CHANNELS = 7
SIZE =130
STEP_SIZE = 40
#satproc
BASE_PATH = "./.."
PATH_IMAGENES_ENTRENAMIENTO = f'/images/{ZONA}/'

GT_FILE = f'{ZONA}_moderate_flood_event.geojson' 
CLASSES = 'M'

#unet
CLASS_WEIGHT = [1]
STEP_PER_EPOCH = 100
N_CLASSES = 1

# %% [markdown]
#
# ## Generacion del data set de entrenamiento
#
#    En esta etapa generamos el dataset de entrenamiento mediante el uso de **GDAL** y **Satproc**. Primero descargamos las imagenes satelitales y utilizamos GDAL para quedarnos con la combinacion de bandas deseada. Luego Utilizamos satproc para generar el dataset con todas las caracteristicas necesarias para el modelo: tamaño , cantidad de imagenes, rango de valores, etc.

# %% [markdown]
# Descargamos las imágenes del bucket

# %%
#creamos la carpeta a donde descargaremos las imagenes
folder = BASE_PATH + PATH_IMAGENES_ENTRENAMIENTO
# !mkdir -p $folder


#!gsutil -m cp -r $bucket   $PATH_images_train

# %% [markdown]
# Podemos verificar que los archivos fueron correctamente descargados

# %%
#!ls $PATH_images_train

# %% [markdown]
# Combinamos todo las imagenes resultantes en un solo vrt

# %%
#!gdalbuildvrt \
#         ../images/file.vrt \
#         ../images/*.tif

# %% [markdown]
# ### Satproc
#
# Con la herramienta **satproc_extract_chips** se generan, a partir de las imágenes descargadas del bucket, imágenes (chips) generalmente mas pequeñas y máscaras (utilizando las anotaciones de verdad de campo).

# %% [markdown]
# **OBS** : tanto las imagenes como el archivo vectorial deben tener la misma georeferencia, por ejemplo 4326

# %%
path_to_files         = f'{BASE_PATH}{PATH_IMAGENES_ENTRENAMIENTO}*.tif' #carpeta a las imagenes
train_output_folder   = f'{BASE_PATH}/dataset/data_train/{ZONA}/'+str(SIZE)+'_'+str(STEP_SIZE)+'/' #carpeta de destino del dataset
vector_file           = f'{BASE_PATH}/data/shp/gt/{GT_FILE}' # archivo vectorial de verdad de campo
vector_file_aoi       = vector_file #archivo vectorial con las zonas de interes

# %%
# !ls ./../images/

# %% [markdown]
# Ejecutamos satproc

# %%
# !satproc_extract_chips \
                $path_to_files \
                -o  $train_output_folder \
                --size $SIZE \
                --step-size $STEP_SIZE \
                --aoi $vector_file_aoi \
                --labels $vector_file \
                --label-property 'class' \
                --classes $CLASSES \
                --rescale \
                --rescale-mode percentiles --lower-cut 0 --upper-cut 100
# Out:
# Rasters:   0%|                                            | 0/1 [00:00<?, ?it/s]
# dataset_global_tegucigalpa_epsg4326.tif windows:   0%|  | 0/504 [00:00<?, ?it/s]
# dataset_global_tegucigalpa_epsg4326.tif windows:   0%| | 1/504 [00:00<01:33,  5.
# dataset_global_tegucigalpa_epsg4326.tif windows:   0%| | 2/504 [00:00<01:21,  6.
# dataset_global_tegucigalpa_epsg4326.tif windows:   1%| | 3/504 [00:00<01:17,  6.
# dataset_global_tegucigalpa_epsg4326.tif windows:   1%| | 4/504 [00:00<01:15,  6.
# dataset_global_tegucigalpa_epsg4326.tif windows:   1%| | 5/504 [00:00<01:14,  6.
# dataset_global_tegucigalpa_epsg4326.tif windows:   1%| | 6/504 [00:00<01:17,  6.
# dataset_global_tegucigalpa_epsg4326.tif windows:   1%| | 7/504 [00:01<01:19,  6.
# dataset_global_tegucigalpa_epsg4326.tif windows:   2%| | 8/504 [00:01<01:20,  6.
# dataset_global_tegucigalpa_epsg4326.tif windows:   2%| | 9/504 [00:01<01:23,  5.
# dataset_global_tegucigalpa_epsg4326.tif windows:   2%| | 10/504 [00:01<01:22,  5
# dataset_global_tegucigalpa_epsg4326.tif windows:   2%| | 11/504 [00:01<01:21,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   2%| | 12/504 [00:01<01:26,  5
# dataset_global_tegucigalpa_epsg4326.tif windows:   3%| | 13/504 [00:02<01:24,  5
# dataset_global_tegucigalpa_epsg4326.tif windows:   3%| | 14/504 [00:02<01:22,  5
# dataset_global_tegucigalpa_epsg4326.tif windows:   3%| | 15/504 [00:02<01:21,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   3%| | 16/504 [00:02<01:20,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   3%| | 17/504 [00:02<01:21,  5
# dataset_global_tegucigalpa_epsg4326.tif windows:   4%| | 18/504 [00:02<01:21,  5
# dataset_global_tegucigalpa_epsg4326.tif windows:   4%| | 19/504 [00:03<01:20,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   4%| | 20/504 [00:03<01:19,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   4%| | 21/504 [00:03<01:18,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   4%| | 22/504 [00:03<01:18,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   5%| | 23/504 [00:03<01:17,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   5%| | 24/504 [00:03<01:17,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   5%| | 25/504 [00:04<01:17,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   5%| | 26/504 [00:04<01:17,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   5%| | 27/504 [00:04<01:16,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   6%| | 28/504 [00:04<01:17,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:   6%| | 29/504 [00:04<01:18,  6
# dataset_global_tegucigalpa_epsg4326.tif windows:  25%|2| 124/504 [00:20<01:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  25%|2| 125/504 [00:20<01:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  25%|2| 126/504 [00:20<01:07,
# dataset_global_tegucigalpa_epsg4326.tif windows:  25%|2| 127/504 [00:20<01:05,
# dataset_global_tegucigalpa_epsg4326.tif windows:  25%|2| 128/504 [00:20<01:04,
# dataset_global_tegucigalpa_epsg4326.tif windows:  26%|2| 129/504 [00:21<01:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  26%|2| 130/504 [00:21<01:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  26%|2| 131/504 [00:21<01:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  26%|2| 132/504 [00:21<01:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  26%|2| 133/504 [00:21<01:01,
# dataset_global_tegucigalpa_epsg4326.tif windows:  27%|2| 134/504 [00:21<01:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  27%|2| 135/504 [00:22<01:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  27%|2| 136/504 [00:22<01:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  27%|2| 137/504 [00:22<01:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  27%|2| 138/504 [00:22<01:01,
# dataset_global_tegucigalpa_epsg4326.tif windows:  28%|2| 139/504 [00:22<01:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  28%|2| 140/504 [00:22<01:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  28%|2| 141/504 [00:23<01:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  28%|2| 142/504 [00:23<00:59,
# dataset_global_tegucigalpa_epsg4326.tif windows:  28%|2| 143/504 [00:23<00:58,
# dataset_global_tegucigalpa_epsg4326.tif windows:  29%|2| 144/504 [00:23<00:58,
# dataset_global_tegucigalpa_epsg4326.tif windows:  29%|2| 145/504 [00:23<00:58,
# dataset_global_tegucigalpa_epsg4326.tif windows:  29%|2| 146/504 [00:23<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  29%|2| 147/504 [00:24<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  29%|2| 148/504 [00:24<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  30%|2| 149/504 [00:24<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  30%|2| 150/504 [00:24<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  30%|2| 151/504 [00:24<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  30%|3| 152/504 [00:24<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  30%|3| 153/504 [00:25<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  31%|3| 154/504 [00:25<00:56,
# dataset_global_tegucigalpa_epsg4326.tif windows:  31%|3| 155/504 [00:25<00:56,
# dataset_global_tegucigalpa_epsg4326.tif windows:  31%|3| 156/504 [00:25<00:56,
# dataset_global_tegucigalpa_epsg4326.tif windows:  31%|3| 157/504 [00:25<00:56,
# dataset_global_tegucigalpa_epsg4326.tif windows:  31%|3| 158/504 [00:25<00:56,
# dataset_global_tegucigalpa_epsg4326.tif windows:  32%|3| 159/504 [00:26<00:57,
# dataset_global_tegucigalpa_epsg4326.tif windows:  32%|3| 160/504 [00:26<00:56,
# dataset_global_tegucigalpa_epsg4326.tif windows:  32%|3| 161/504 [00:26<00:55,
# dataset_global_tegucigalpa_epsg4326.tif windows:  32%|3| 162/504 [00:26<00:54,
# dataset_global_tegucigalpa_epsg4326.tif windows:  32%|3| 163/504 [00:26<00:53,
# dataset_global_tegucigalpa_epsg4326.tif windows:  33%|3| 164/504 [00:26<00:53,
# dataset_global_tegucigalpa_epsg4326.tif windows:  33%|3| 165/504 [00:26<00:52,
# dataset_global_tegucigalpa_epsg4326.tif windows:  33%|3| 166/504 [00:27<00:52,
# dataset_global_tegucigalpa_epsg4326.tif windows:  33%|3| 167/504 [00:27<00:52,
# dataset_global_tegucigalpa_epsg4326.tif windows:  33%|3| 168/504 [00:27<00:52,
# dataset_global_tegucigalpa_epsg4326.tif windows:  34%|3| 169/504 [00:27<00:52,
# dataset_global_tegucigalpa_epsg4326.tif windows:  34%|3| 170/504 [00:27<00:52,
# dataset_global_tegucigalpa_epsg4326.tif windows:  34%|3| 171/504 [00:27<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  34%|3| 172/504 [00:28<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  34%|3| 173/504 [00:28<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  35%|3| 174/504 [00:28<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  35%|3| 175/504 [00:28<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  35%|3| 176/504 [00:28<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  35%|3| 177/504 [00:28<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  35%|3| 178/504 [00:29<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  36%|3| 179/504 [00:29<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  36%|3| 180/504 [00:29<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  36%|3| 181/504 [00:29<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  36%|3| 182/504 [00:29<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  36%|3| 183/504 [00:29<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  37%|3| 184/504 [00:29<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  37%|3| 185/504 [00:30<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  37%|3| 186/504 [00:30<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  37%|3| 187/504 [00:30<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  37%|3| 188/504 [00:30<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  38%|3| 189/504 [00:30<00:51,
# dataset_global_tegucigalpa_epsg4326.tif windows:  38%|3| 190/504 [00:30<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  38%|3| 191/504 [00:31<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  38%|3| 192/504 [00:31<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  38%|3| 193/504 [00:31<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  38%|3| 194/504 [00:31<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  39%|3| 195/504 [00:31<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  39%|3| 196/504 [00:31<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  39%|3| 197/504 [00:32<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  39%|3| 198/504 [00:32<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  39%|3| 199/504 [00:32<00:49,
# dataset_global_tegucigalpa_epsg4326.tif windows:  40%|3| 200/504 [00:32<00:49,
# dataset_global_tegucigalpa_epsg4326.tif windows:  40%|3| 201/504 [00:32<00:49,
# dataset_global_tegucigalpa_epsg4326.tif windows:  40%|4| 202/504 [00:32<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  40%|4| 203/504 [00:33<00:50,
# dataset_global_tegucigalpa_epsg4326.tif windows:  40%|4| 204/504 [00:33<00:49,
# dataset_global_tegucigalpa_epsg4326.tif windows:  41%|4| 205/504 [00:33<00:48,
# dataset_global_tegucigalpa_epsg4326.tif windows:  41%|4| 206/504 [00:33<00:48,
# dataset_global_tegucigalpa_epsg4326.tif windows:  41%|4| 207/504 [00:33<00:47,
# dataset_global_tegucigalpa_epsg4326.tif windows:  41%|4| 208/504 [00:33<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  41%|4| 209/504 [00:34<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  42%|4| 210/504 [00:34<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  42%|4| 211/504 [00:34<00:47,
# dataset_global_tegucigalpa_epsg4326.tif windows:  42%|4| 212/504 [00:34<00:47,
# dataset_global_tegucigalpa_epsg4326.tif windows:  42%|4| 213/504 [00:34<00:47,
# dataset_global_tegucigalpa_epsg4326.tif windows:  42%|4| 214/504 [00:34<00:47,
# dataset_global_tegucigalpa_epsg4326.tif windows:  43%|4| 215/504 [00:35<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  43%|4| 216/504 [00:35<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  43%|4| 217/504 [00:35<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  43%|4| 218/504 [00:35<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  43%|4| 219/504 [00:35<00:46,
# dataset_global_tegucigalpa_epsg4326.tif windows:  44%|4| 220/504 [00:35<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  44%|4| 221/504 [00:35<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  44%|4| 222/504 [00:36<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  44%|4| 223/504 [00:36<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  44%|4| 224/504 [00:36<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  45%|4| 225/504 [00:36<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  45%|4| 226/504 [00:36<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  45%|4| 227/504 [00:36<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  45%|4| 228/504 [00:37<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  45%|4| 229/504 [00:37<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  46%|4| 230/504 [00:37<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  46%|4| 231/504 [00:37<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  46%|4| 232/504 [00:37<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  46%|4| 233/504 [00:37<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  46%|4| 234/504 [00:38<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  47%|4| 235/504 [00:38<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  47%|4| 236/504 [00:38<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  47%|4| 237/504 [00:38<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  47%|4| 238/504 [00:38<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  47%|4| 239/504 [00:38<00:42,
# dataset_global_tegucigalpa_epsg4326.tif windows:  48%|4| 240/504 [00:39<00:45,
# dataset_global_tegucigalpa_epsg4326.tif windows:  48%|4| 241/504 [00:39<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  48%|4| 242/504 [00:39<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  48%|4| 243/504 [00:39<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  48%|4| 244/504 [00:39<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  49%|4| 245/504 [00:39<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  49%|4| 246/504 [00:40<00:44,
# dataset_global_tegucigalpa_epsg4326.tif windows:  49%|4| 247/504 [00:40<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  49%|4| 248/504 [00:40<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  49%|4| 249/504 [00:40<00:42,
# dataset_global_tegucigalpa_epsg4326.tif windows:  50%|4| 250/504 [00:40<00:43,
# dataset_global_tegucigalpa_epsg4326.tif windows:  50%|4| 251/504 [00:40<00:42,
# dataset_global_tegucigalpa_epsg4326.tif windows:  50%|5| 252/504 [00:41<00:42,
# dataset_global_tegucigalpa_epsg4326.tif windows:  50%|5| 253/504 [00:41<00:41,
# dataset_global_tegucigalpa_epsg4326.tif windows:  50%|5| 254/504 [00:41<00:41,
# dataset_global_tegucigalpa_epsg4326.tif windows:  51%|5| 255/504 [00:41<00:40,
# dataset_global_tegucigalpa_epsg4326.tif windows:  51%|5| 256/504 [00:41<00:40,
# dataset_global_tegucigalpa_epsg4326.tif windows:  51%|5| 257/504 [00:41<00:40,
# dataset_global_tegucigalpa_epsg4326.tif windows:  51%|5| 258/504 [00:42<00:39,
# dataset_global_tegucigalpa_epsg4326.tif windows:  51%|5| 259/504 [00:42<00:39,
# dataset_global_tegucigalpa_epsg4326.tif windows:  52%|5| 260/504 [00:42<00:39,
# dataset_global_tegucigalpa_epsg4326.tif windows:  52%|5| 261/504 [00:42<00:39,
# dataset_global_tegucigalpa_epsg4326.tif windows:  52%|5| 262/504 [00:42<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  52%|5| 263/504 [00:42<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  52%|5| 264/504 [00:43<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  53%|5| 265/504 [00:43<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  53%|5| 266/504 [00:43<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  53%|5| 267/504 [00:43<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  53%|5| 268/504 [00:43<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  53%|5| 269/504 [00:43<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  54%|5| 270/504 [00:44<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  54%|5| 271/504 [00:44<00:37,
# dataset_global_tegucigalpa_epsg4326.tif windows:  54%|5| 272/504 [00:44<00:37,
# dataset_global_tegucigalpa_epsg4326.tif windows:  54%|5| 273/504 [00:44<00:37,
# dataset_global_tegucigalpa_epsg4326.tif windows:  54%|5| 274/504 [00:44<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  55%|5| 275/504 [00:44<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  55%|5| 276/504 [00:45<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  55%|5| 277/504 [00:45<00:38,
# dataset_global_tegucigalpa_epsg4326.tif windows:  55%|5| 278/504 [00:45<00:37,
# dataset_global_tegucigalpa_epsg4326.tif windows:  55%|5| 279/504 [00:45<00:37,
# dataset_global_tegucigalpa_epsg4326.tif windows:  56%|5| 280/504 [00:45<00:36,
# dataset_global_tegucigalpa_epsg4326.tif windows:  56%|5| 281/504 [00:45<00:36,
# dataset_global_tegucigalpa_epsg4326.tif windows:  56%|5| 282/504 [00:46<00:37,
# dataset_global_tegucigalpa_epsg4326.tif windows:  56%|5| 283/504 [00:46<00:37,
# dataset_global_tegucigalpa_epsg4326.tif windows:  56%|5| 284/504 [00:46<00:36,
# dataset_global_tegucigalpa_epsg4326.tif windows:  57%|5| 285/504 [00:46<00:36,
# dataset_global_tegucigalpa_epsg4326.tif windows:  57%|5| 286/504 [00:46<00:35,
# dataset_global_tegucigalpa_epsg4326.tif windows:  57%|5| 287/504 [00:46<00:35,
# dataset_global_tegucigalpa_epsg4326.tif windows:  57%|5| 288/504 [00:47<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  57%|5| 289/504 [00:47<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  58%|5| 290/504 [00:47<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  58%|5| 291/504 [00:47<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  58%|5| 292/504 [00:47<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  58%|5| 293/504 [00:47<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  58%|5| 294/504 [00:48<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  59%|5| 295/504 [00:48<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  59%|5| 296/504 [00:48<00:33,
# dataset_global_tegucigalpa_epsg4326.tif windows:  59%|5| 297/504 [00:48<00:34,
# dataset_global_tegucigalpa_epsg4326.tif windows:  59%|5| 298/504 [00:48<00:33,
# dataset_global_tegucigalpa_epsg4326.tif windows:  59%|5| 299/504 [00:48<00:33,
# dataset_global_tegucigalpa_epsg4326.tif windows:  60%|5| 300/504 [00:49<00:33,
# dataset_global_tegucigalpa_epsg4326.tif windows:  60%|5| 301/504 [00:49<00:33,
# dataset_global_tegucigalpa_epsg4326.tif windows:  60%|5| 302/504 [00:49<00:33,
# dataset_global_tegucigalpa_epsg4326.tif windows:  60%|6| 303/504 [00:49<00:33,
# dataset_global_tegucigalpa_epsg4326.tif windows:  60%|6| 304/504 [00:49<00:32,
# dataset_global_tegucigalpa_epsg4326.tif windows:  61%|6| 305/504 [00:49<00:32,
# dataset_global_tegucigalpa_epsg4326.tif windows:  61%|6| 306/504 [00:49<00:32,
# dataset_global_tegucigalpa_epsg4326.tif windows:  61%|6| 307/504 [00:50<00:31,
# dataset_global_tegucigalpa_epsg4326.tif windows:  61%|6| 308/504 [00:50<00:31,
# dataset_global_tegucigalpa_epsg4326.tif windows:  61%|6| 309/504 [00:50<00:31,
# dataset_global_tegucigalpa_epsg4326.tif windows:  62%|6| 310/504 [00:50<00:31,
# dataset_global_tegucigalpa_epsg4326.tif windows:  62%|6| 311/504 [00:50<00:30,
# dataset_global_tegucigalpa_epsg4326.tif windows:  62%|6| 312/504 [00:50<00:30,
# dataset_global_tegucigalpa_epsg4326.tif windows:  62%|6| 313/504 [00:51<00:30,
# dataset_global_tegucigalpa_epsg4326.tif windows:  62%|6| 314/504 [00:51<00:30,
# dataset_global_tegucigalpa_epsg4326.tif windows:  62%|6| 315/504 [00:51<00:30,
# dataset_global_tegucigalpa_epsg4326.tif windows:  63%|6| 316/504 [00:51<00:30,
# dataset_global_tegucigalpa_epsg4326.tif windows:  69%|6| 349/504 [00:56<00:25,
# dataset_global_tegucigalpa_epsg4326.tif windows:  69%|6| 350/504 [00:57<00:25,
# dataset_global_tegucigalpa_epsg4326.tif windows:  70%|6| 351/504 [00:57<00:25,
# dataset_global_tegucigalpa_epsg4326.tif windows:  70%|6| 352/504 [00:57<00:24,
# dataset_global_tegucigalpa_epsg4326.tif windows:  70%|7| 353/504 [00:57<00:24,
# dataset_global_tegucigalpa_epsg4326.tif windows:  70%|7| 354/504 [00:57<00:25,
# dataset_global_tegucigalpa_epsg4326.tif windows:  70%|7| 355/504 [00:57<00:24,
# dataset_global_tegucigalpa_epsg4326.tif windows:  71%|7| 356/504 [00:58<00:24,
# dataset_global_tegucigalpa_epsg4326.tif windows:  71%|7| 357/504 [00:58<00:24,
# dataset_global_tegucigalpa_epsg4326.tif windows:  71%|7| 358/504 [00:58<00:24,
# dataset_global_tegucigalpa_epsg4326.tif windows:  71%|7| 359/504 [00:58<00:23,
# dataset_global_tegucigalpa_epsg4326.tif windows:  71%|7| 360/504 [00:58<00:23,
# dataset_global_tegucigalpa_epsg4326.tif windows:  72%|7| 361/504 [00:58<00:22,
# dataset_global_tegucigalpa_epsg4326.tif windows:  72%|7| 362/504 [00:59<00:22,
# dataset_global_tegucigalpa_epsg4326.tif windows:  72%|7| 363/504 [00:59<00:22,
# dataset_global_tegucigalpa_epsg4326.tif windows:  72%|7| 364/504 [00:59<00:22,
# dataset_global_tegucigalpa_epsg4326.tif windows:  72%|7| 365/504 [00:59<00:22,
# dataset_global_tegucigalpa_epsg4326.tif windows:  73%|7| 366/504 [00:59<00:22,
# dataset_global_tegucigalpa_epsg4326.tif windows:  73%|7| 367/504 [00:59<00:22,
# dataset_global_tegucigalpa_epsg4326.tif windows:  73%|7| 368/504 [01:00<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  73%|7| 369/504 [01:00<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  73%|7| 370/504 [01:00<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  74%|7| 371/504 [01:00<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  74%|7| 372/504 [01:00<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  74%|7| 373/504 [01:00<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  74%|7| 374/504 [01:01<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  74%|7| 375/504 [01:01<00:21,
# dataset_global_tegucigalpa_epsg4326.tif windows:  75%|7| 376/504 [01:01<00:20,
# dataset_global_tegucigalpa_epsg4326.tif windows:  75%|7| 377/504 [01:01<00:20,
# dataset_global_tegucigalpa_epsg4326.tif windows:  75%|7| 378/504 [01:01<00:20,
# dataset_global_tegucigalpa_epsg4326.tif windows:  75%|7| 379/504 [01:01<00:20,
# dataset_global_tegucigalpa_epsg4326.tif windows:  75%|7| 380/504 [01:01<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  76%|7| 381/504 [01:02<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  76%|7| 382/504 [01:02<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  76%|7| 383/504 [01:02<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  76%|7| 384/504 [01:02<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  76%|7| 385/504 [01:02<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  77%|7| 386/504 [01:02<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  77%|7| 387/504 [01:03<00:19,
# dataset_global_tegucigalpa_epsg4326.tif windows:  77%|7| 388/504 [01:03<00:18,
# dataset_global_tegucigalpa_epsg4326.tif windows:  77%|7| 389/504 [01:03<00:18,
# dataset_global_tegucigalpa_epsg4326.tif windows:  77%|7| 390/504 [01:03<00:18,
# dataset_global_tegucigalpa_epsg4326.tif windows:  78%|7| 391/504 [01:03<00:18,
# dataset_global_tegucigalpa_epsg4326.tif windows:  78%|7| 392/504 [01:03<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  78%|7| 393/504 [01:04<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  78%|7| 394/504 [01:04<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  78%|7| 395/504 [01:04<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  79%|7| 396/504 [01:04<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  79%|7| 397/504 [01:04<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  79%|7| 398/504 [01:04<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  79%|7| 399/504 [01:05<00:17,
# dataset_global_tegucigalpa_epsg4326.tif windows:  79%|7| 400/504 [01:05<00:16,
# dataset_global_tegucigalpa_epsg4326.tif windows:  80%|7| 401/504 [01:05<00:16,
# dataset_global_tegucigalpa_epsg4326.tif windows:  80%|7| 402/504 [01:05<00:16,
# dataset_global_tegucigalpa_epsg4326.tif windows:  80%|7| 403/504 [01:05<00:16,
# dataset_global_tegucigalpa_epsg4326.tif windows:  80%|8| 404/504 [01:05<00:16,
# dataset_global_tegucigalpa_epsg4326.tif windows:  80%|8| 405/504 [01:06<00:16,
# dataset_global_tegucigalpa_epsg4326.tif windows:  81%|8| 406/504 [01:06<00:15,
# dataset_global_tegucigalpa_epsg4326.tif windows:  81%|8| 407/504 [01:06<00:15,
# dataset_global_tegucigalpa_epsg4326.tif windows:  81%|8| 408/504 [01:06<00:15,
# dataset_global_tegucigalpa_epsg4326.tif windows:  81%|8| 409/504 [01:06<00:15,
# dataset_global_tegucigalpa_epsg4326.tif windows:  81%|8| 410/504 [01:06<00:15,
# dataset_global_tegucigalpa_epsg4326.tif windows:  82%|8| 411/504 [01:07<00:15,
# dataset_global_tegucigalpa_epsg4326.tif windows:  82%|8| 412/504 [01:07<00:15,
# dataset_global_tegucigalpa_epsg4326.tif windows:  82%|8| 413/504 [01:07<00:14,
# dataset_global_tegucigalpa_epsg4326.tif windows:  82%|8| 414/504 [01:07<00:14,
# dataset_global_tegucigalpa_epsg4326.tif windows:  82%|8| 415/504 [01:07<00:14,
# dataset_global_tegucigalpa_epsg4326.tif windows:  83%|8| 416/504 [01:07<00:14,
# dataset_global_tegucigalpa_epsg4326.tif windows:  83%|8| 417/504 [01:07<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  83%|8| 418/504 [01:08<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  83%|8| 419/504 [01:08<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  83%|8| 420/504 [01:08<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  84%|8| 421/504 [01:08<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  84%|8| 422/504 [01:08<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  84%|8| 423/504 [01:08<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  84%|8| 424/504 [01:09<00:13,
# dataset_global_tegucigalpa_epsg4326.tif windows:  84%|8| 425/504 [01:09<00:12,
# dataset_global_tegucigalpa_epsg4326.tif windows:  85%|8| 426/504 [01:09<00:12,
# dataset_global_tegucigalpa_epsg4326.tif windows:  85%|8| 427/504 [01:09<00:12,
# dataset_global_tegucigalpa_epsg4326.tif windows:  85%|8| 428/504 [01:09<00:12,
# dataset_global_tegucigalpa_epsg4326.tif windows:  85%|8| 429/504 [01:09<00:12,
# dataset_global_tegucigalpa_epsg4326.tif windows:  85%|8| 430/504 [01:10<00:11,
# dataset_global_tegucigalpa_epsg4326.tif windows:  86%|8| 431/504 [01:10<00:11,
# dataset_global_tegucigalpa_epsg4326.tif windows:  86%|8| 432/504 [01:10<00:11,
# dataset_global_tegucigalpa_epsg4326.tif windows:  86%|8| 433/504 [01:10<00:11,
# dataset_global_tegucigalpa_epsg4326.tif windows:  86%|8| 434/504 [01:10<00:11,
# dataset_global_tegucigalpa_epsg4326.tif windows:  86%|8| 435/504 [01:10<00:10,
# dataset_global_tegucigalpa_epsg4326.tif windows:  87%|8| 436/504 [01:11<00:10,
# dataset_global_tegucigalpa_epsg4326.tif windows:  87%|8| 437/504 [01:11<00:10,
# dataset_global_tegucigalpa_epsg4326.tif windows:  87%|8| 438/504 [01:11<00:10,
# dataset_global_tegucigalpa_epsg4326.tif windows:  87%|8| 439/504 [01:11<00:10,
# dataset_global_tegucigalpa_epsg4326.tif windows:  87%|8| 440/504 [01:11<00:10,
# dataset_global_tegucigalpa_epsg4326.tif windows:  88%|8| 441/504 [01:11<00:10,
# dataset_global_tegucigalpa_epsg4326.tif windows:  88%|8| 442/504 [01:12<00:09,
# dataset_global_tegucigalpa_epsg4326.tif windows:  88%|8| 443/504 [01:12<00:09,
# dataset_global_tegucigalpa_epsg4326.tif windows:  88%|8| 444/504 [01:12<00:09,
# dataset_global_tegucigalpa_epsg4326.tif windows:  95%|9| 477/504 [01:17<00:04,
# dataset_global_tegucigalpa_epsg4326.tif windows:  95%|9| 478/504 [01:17<00:04,
# dataset_global_tegucigalpa_epsg4326.tif windows:  95%|9| 479/504 [01:18<00:04,
# dataset_global_tegucigalpa_epsg4326.tif windows:  95%|9| 480/504 [01:18<00:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  95%|9| 481/504 [01:18<00:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  96%|9| 482/504 [01:18<00:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  96%|9| 483/504 [01:18<00:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  96%|9| 484/504 [01:18<00:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  96%|9| 485/504 [01:19<00:03,
# dataset_global_tegucigalpa_epsg4326.tif windows:  96%|9| 486/504 [01:19<00:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  97%|9| 487/504 [01:19<00:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  97%|9| 488/504 [01:19<00:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  97%|9| 489/504 [01:19<00:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  97%|9| 490/504 [01:19<00:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  97%|9| 491/504 [01:20<00:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  98%|9| 492/504 [01:20<00:02,
# dataset_global_tegucigalpa_epsg4326.tif windows:  98%|9| 493/504 [01:20<00:01,
# dataset_global_tegucigalpa_epsg4326.tif windows:  98%|9| 494/504 [01:20<00:01,
# dataset_global_tegucigalpa_epsg4326.tif windows:  98%|9| 495/504 [01:20<00:01,
# dataset_global_tegucigalpa_epsg4326.tif windows:  98%|9| 496/504 [01:20<00:01,
# dataset_global_tegucigalpa_epsg4326.tif windows:  99%|9| 497/504 [01:21<00:01,
# dataset_global_tegucigalpa_epsg4326.tif windows:  99%|9| 498/504 [01:21<00:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  99%|9| 499/504 [01:21<00:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  99%|9| 500/504 [01:21<00:00,
# dataset_global_tegucigalpa_epsg4326.tif windows:  99%|9| 501/504 [01:21<00:00,
# dataset_global_tegucigalpa_epsg4326.tif windows: 100%|9| 502/504 [01:21<00:00,
# dataset_global_tegucigalpa_epsg4326.tif windows: 100%|9| 503/504 [01:22<00:00,
# dataset_global_tegucigalpa_epsg4326.tif windows: 100%|#| 504/504 [01:22<00:00,
# Rasters: 100%|####################################| 1/1 [01:23<00:00, 83.97s/it]

# %% [markdown]
# ###### Los argumentos:
#
# * **path_to_files** es la ruta a las imágenes
#
# * **o** es la ruta de destino
#
# Recomendamos que dicha ruta sea descriptiva, por ejemplo “data_train/120_40/ ” describe : Data_train → datos usados para entrenar; 120_40 → <tamaño de la imagen >_ <tamaño del step-size>
#
# * **size** tamaño de las imágenes resultantes o chips (las imágenes son cuadradas)
# * **step-size** paso del proceso. Debe ser menor o igual a *size*. Si *step-size* es igual que el *size* entonces no hay overlap en las imágenes resultantes.
#
# En ocaciones es útil para el entrenamiento generar los chips con un overlap de este modo tenemos más datos para entrenar.
#
#
# * **label-property** nombre del campo donde se define cada categoría (solo se usa para el entrenamiento)
#
# * **classes** nombres de las clases (como aparecen en el geojson), separados por espacios
#
# * **aoi** ruta al archivo vectorial donde están definidas las anotaciones. Al definir una region de interés solo se procesan las imágenes que interceptan esas anotaciones.
#
# * **rescale** lleva los valores de las bandas a 0-255
#
# Este comando va a generar dos carpetas en la ruta de destino : “images” y “extent”. Los archivos de la primera van a ser de tipo Tiff de 3 bandas (rgb) y los de la segunda van a ser, también, de tipo Tiff pero de N bandas donde N representa el número de clases, en este caso sólo una. Y donde cada una de las bandas es una máscara binaria

# %% [markdown]
# ## Entrenamiento
#
# Generamos el entrenamiento del modelo utilizando los datasets creados en el paso previo. El modelo es una red neuronal CNN basado en la arquitectura U-Net. Este considera las imágenes y las máscaras binarias como inputs y genera una imagen con la probabilidad de encontrar al objeto de interés.

# %%
from unetseg.train import TrainConfig, train
from unetseg.evaluate import plot_data_generator
import os
# Out:
# 2022-05-19 20:22:35.658768: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/cv2/../../lib64:
# 2022-05-19 20:22:35.658803: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# En esta etapa debemos definir la configuración del modelo de ML.

# %%
model_name = f'UNet_{ZONA}_160x160_{str(SIZE)}_{str(STEP_SIZE)}_spe{STEP_PER_EPOCH}.h5'

# %%
config = TrainConfig(width=160,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc; y no menor a 80)
                     height=160,
                     n_channels=N_CHANNELS,  #  número de canales de la imagen, rgb -> 3
                     n_classes=N_CLASSES, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes (rotación,)
                     seed=42,
                     epochs=20, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=16, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch=STEP_PER_EPOCH, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience=5, # a medida que entrena se guardan los resultados del entrenamiento despues de cada epoch, si el error no varió luego de ¿¿10 ?? iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.1, # se divide la muestra en training (80% de los datos) y validation (20% de los datos) para calcular el error durante el proceso de entrenamiento
                     test_split=0.1, # Cantidad de imágenes del dataset
                     images_path=train_output_folder,#ruta a las imágenes generadas con Satproc
                     model_path=os.path.join(BASE_PATH,'data/weights/', model_name),#  ruta del modelo entrenado
                     model_architecture='unet',
                     evaluate=True  ,
                     class_weights= CLASS_WEIGHT)

# %% [markdown]
# *Obs*: Es util usar un nombre para el archivo de pesos que de información sobre los parametros de entrenamiento. por ejemplo: < modelo >_< proyecto >_< dim_de_las_imagenes >_< size >_< step_size >_< step_per_epoch >.h5 o similares

# %% [markdown]
# Podemos visualizar alguna de las imágenes y máscaras del dataset de entrenamiento. A la izquierda se muestra la imágen y a la derecha la máscara

# %%
plot_data_generator(num_samples=3, fig_size=(20, 20), train_config=config,img_ch =3)

# %% [markdown]
# Corremos el entrenamiento.

# %%
res_config = train(config)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 160, 160, 7  0           []
#                                 )]
#
#  conv2d_69 (Conv2D)             (None, 160, 160, 32  2048        ['input_4[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 160, 160, 32  9248        ['conv2d_69[0][0]']
#                                 )
#
#  max_pooling2d_15 (MaxPooling2D  (None, 80, 80, 32)  0           ['conv2d_70[0][0]']
#  )
#
#  batch_normalization_24 (BatchN  (None, 80, 80, 32)  128         ['max_pooling2d_15[0][0]']
#  ormalization)
#
#  conv2d_71 (Conv2D)             (None, 80, 80, 64)   18496       ['batch_normalization_24[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 80, 80, 64)   36928       ['conv2d_71[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 40, 40, 64)  0           ['conv2d_72[0][0]']
#  )
#
#  dropout_24 (Dropout)           (None, 40, 40, 64)   0           ['max_pooling2d_16[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 40, 40, 64)  256         ['dropout_24[0][0]']
#  ormalization)
#
#  conv2d_73 (Conv2D)             (None, 40, 40, 128)  73856       ['batch_normalization_25[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 40, 40, 128)  147584      ['conv2d_73[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 20, 20, 128)  0          ['conv2d_74[0][0]']
#  )
#
#  dropout_25 (Dropout)           (None, 20, 20, 128)  0           ['max_pooling2d_17[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 20, 20, 128)  512        ['dropout_25[0][0]']
#  ormalization)
#
#  conv2d_75 (Conv2D)             (None, 20, 20, 256)  295168      ['batch_normalization_26[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 20, 20, 256)  590080      ['conv2d_75[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 10, 10, 256)  0          ['conv2d_76[0][0]']
#  )
#
#  dropout_26 (Dropout)           (None, 10, 10, 256)  0           ['max_pooling2d_18[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 10, 10, 256)  1024       ['dropout_26[0][0]']
#  ormalization)
#
#  conv2d_77 (Conv2D)             (None, 10, 10, 512)  1180160     ['batch_normalization_27[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 10, 10, 512)  2359808     ['conv2d_77[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 5, 5, 512)   0           ['conv2d_78[0][0]']
#  )
#
#  dropout_27 (Dropout)           (None, 5, 5, 512)    0           ['max_pooling2d_19[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 5, 5, 1024)   4719616     ['dropout_27[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 5, 5, 1024)   9438208     ['conv2d_79[0][0]']
#
#  conv2d_transpose_15 (Conv2DTra  (None, 10, 10, 512)  2097664    ['conv2d_80[0][0]']
#  nspose)
#
#  concatenate_15 (Concatenate)   (None, 10, 10, 1024  0           ['conv2d_transpose_15[0][0]',
#                                 )                                 'conv2d_78[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 10, 10, 1024  4096       ['concatenate_15[0][0]']
#  ormalization)                  )
#
#  conv2d_81 (Conv2D)             (None, 10, 10, 512)  4719104     ['batch_normalization_28[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 10, 10, 512)  2359808     ['conv2d_81[0][0]']
#
#  dropout_28 (Dropout)           (None, 10, 10, 512)  0           ['conv2d_82[0][0]']
#
#  conv2d_transpose_16 (Conv2DTra  (None, 20, 20, 256)  524544     ['dropout_28[0][0]']
#  nspose)
#
#  concatenate_16 (Concatenate)   (None, 20, 20, 512)  0           ['conv2d_transpose_16[0][0]',
#                                                                   'conv2d_76[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 20, 20, 512)  2048       ['concatenate_16[0][0]']
#  ormalization)
#
#  conv2d_83 (Conv2D)             (None, 20, 20, 256)  1179904     ['batch_normalization_29[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 20, 20, 256)  590080      ['conv2d_83[0][0]']
#
#  dropout_29 (Dropout)           (None, 20, 20, 256)  0           ['conv2d_84[0][0]']
#
#  conv2d_transpose_17 (Conv2DTra  (None, 40, 40, 128)  131200     ['dropout_29[0][0]']
#  nspose)
#
#  concatenate_17 (Concatenate)   (None, 40, 40, 256)  0           ['conv2d_transpose_17[0][0]',
#                                                                   'conv2d_74[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 40, 40, 256)  1024       ['concatenate_17[0][0]']
#  ormalization)
#
#  conv2d_85 (Conv2D)             (None, 40, 40, 128)  295040      ['batch_normalization_30[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 40, 40, 128)  147584      ['conv2d_85[0][0]']
#
#  dropout_30 (Dropout)           (None, 40, 40, 128)  0           ['conv2d_86[0][0]']
#
#  conv2d_transpose_18 (Conv2DTra  (None, 80, 80, 64)  32832       ['dropout_30[0][0]']
#  nspose)
#
#  concatenate_18 (Concatenate)   (None, 80, 80, 128)  0           ['conv2d_transpose_18[0][0]',
#                                                                   'conv2d_72[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 80, 80, 128)  512        ['concatenate_18[0][0]']
#  ormalization)
#
#  conv2d_87 (Conv2D)             (None, 80, 80, 64)   73792       ['batch_normalization_31[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 80, 80, 64)   36928       ['conv2d_87[0][0]']
#
#  dropout_31 (Dropout)           (None, 80, 80, 64)   0           ['conv2d_88[0][0]']
#
#  conv2d_transpose_19 (Conv2DTra  (None, 160, 160, 32  8224       ['dropout_31[0][0]']
#  nspose)                        )
#
#  concatenate_19 (Concatenate)   (None, 160, 160, 64  0           ['conv2d_transpose_19[0][0]',
#                                 )                                 'conv2d_70[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 160, 160, 32  18464       ['concatenate_19[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 160, 160, 32  9248        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 160, 160, 1)  33          ['conv2d_90[0][0]']
#
# ==================================================================================================
# Total params: 31,105,249
# Trainable params: 31,100,449
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 501
# Num. training images: 406
# Num. validation images: 45
# Num. test images: 50
# Compile and fit the UNet model
# Epoch 1/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2193 - mean_io_u_3: 0.4808
# Epoch 00001: val_loss improved from inf to 0.10488, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 749s 7s/step - loss: 0.2193 - mean_io_u_3: 0.4808 - val_loss: 0.1049 - val_mean_io_u_3: 0.4840
# Epoch 2/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1028 - mean_io_u_3: 0.4809
# Epoch 00002: val_loss did not improve from 0.10488
# 100/100 [==============================] - 735s 7s/step - loss: 0.1028 - mean_io_u_3: 0.4809 - val_loss: 0.5544 - val_mean_io_u_3: 0.4813
# Epoch 3/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0991 - mean_io_u_3: 0.4800
# Epoch 00003: val_loss improved from 0.10488 to 0.09803, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 726s 7s/step - loss: 0.0991 - mean_io_u_3: 0.4800 - val_loss: 0.0980 - val_mean_io_u_3: 0.4834
# Epoch 4/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0954 - mean_io_u_3: 0.4794
# Epoch 00004: val_loss did not improve from 0.09803
# 100/100 [==============================] - 726s 7s/step - loss: 0.0954 - mean_io_u_3: 0.4794 - val_loss: 0.1092 - val_mean_io_u_3: 0.4836
# Epoch 5/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0904 - mean_io_u_3: 0.4806
# Epoch 00005: val_loss improved from 0.09803 to 0.08815, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 730s 7s/step - loss: 0.0904 - mean_io_u_3: 0.4806 - val_loss: 0.0881 - val_mean_io_u_3: 0.4830
# Epoch 6/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0884 - mean_io_u_3: 0.4797
# Epoch 00006: val_loss did not improve from 0.08815
# 100/100 [==============================] - 728s 7s/step - loss: 0.0884 - mean_io_u_3: 0.4797 - val_loss: 0.1037 - val_mean_io_u_3: 0.4811
# Epoch 7/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0821 - mean_io_u_3: 0.4814
# Epoch 00007: val_loss did not improve from 0.08815
# 100/100 [==============================] - 724s 7s/step - loss: 0.0821 - mean_io_u_3: 0.4814 - val_loss: 0.0926 - val_mean_io_u_3: 0.4806
# Epoch 8/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0837 - mean_io_u_3: 0.4803
# Epoch 00008: val_loss improved from 0.08815 to 0.08630, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 725s 7s/step - loss: 0.0837 - mean_io_u_3: 0.4803 - val_loss: 0.0863 - val_mean_io_u_3: 0.4801
# Epoch 9/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0821 - mean_io_u_3: 0.4795
# Epoch 00009: val_loss improved from 0.08630 to 0.08214, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 728s 7s/step - loss: 0.0821 - mean_io_u_3: 0.4795 - val_loss: 0.0821 - val_mean_io_u_3: 0.4844
# Epoch 10/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0812 - mean_io_u_3: 0.4800
# Epoch 00010: val_loss did not improve from 0.08214
# 100/100 [==============================] - 725s 7s/step - loss: 0.0812 - mean_io_u_3: 0.4800 - val_loss: 0.0959 - val_mean_io_u_3: 0.4821
# Epoch 11/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0791 - mean_io_u_3: 0.4803
# Epoch 00011: val_loss improved from 0.08214 to 0.07999, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 728s 7s/step - loss: 0.0791 - mean_io_u_3: 0.4803 - val_loss: 0.0800 - val_mean_io_u_3: 0.4844
# Epoch 12/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0743 - mean_io_u_3: 0.4807
# Epoch 00012: val_loss did not improve from 0.07999
# 100/100 [==============================] - 729s 7s/step - loss: 0.0743 - mean_io_u_3: 0.4807 - val_loss: 0.0918 - val_mean_io_u_3: 0.4804
# Epoch 13/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0777 - mean_io_u_3: 0.4795
# Epoch 00013: val_loss did not improve from 0.07999
# 100/100 [==============================] - 734s 7s/step - loss: 0.0777 - mean_io_u_3: 0.4795 - val_loss: 0.0870 - val_mean_io_u_3: 0.4834
# Epoch 14/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0742 - mean_io_u_3: 0.4801
# Epoch 00014: val_loss improved from 0.07999 to 0.07552, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 745s 7s/step - loss: 0.0742 - mean_io_u_3: 0.4801 - val_loss: 0.0755 - val_mean_io_u_3: 0.4820
# Epoch 15/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0709 - mean_io_u_3: 0.4804
# Epoch 00015: val_loss improved from 0.07552 to 0.07179, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 761s 8s/step - loss: 0.0709 - mean_io_u_3: 0.4804 - val_loss: 0.0718 - val_mean_io_u_3: 0.4821
# Epoch 16/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0727 - mean_io_u_3: 0.4798
# Epoch 00016: val_loss did not improve from 0.07179
# 100/100 [==============================] - 755s 8s/step - loss: 0.0727 - mean_io_u_3: 0.4798 - val_loss: 0.0841 - val_mean_io_u_3: 0.4817
# Epoch 17/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0701 - mean_io_u_3: 0.4801
# Epoch 00017: val_loss did not improve from 0.07179
# 100/100 [==============================] - 757s 8s/step - loss: 0.0701 - mean_io_u_3: 0.4801 - val_loss: 0.0762 - val_mean_io_u_3: 0.4815
# Epoch 18/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0676 - mean_io_u_3: 0.4811
# Epoch 00018: val_loss did not improve from 0.07179
# 100/100 [==============================] - 759s 8s/step - loss: 0.0676 - mean_io_u_3: 0.4811 - val_loss: 0.0718 - val_mean_io_u_3: 0.4818
# Epoch 19/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0695 - mean_io_u_3: 0.4810
# Epoch 00019: val_loss did not improve from 0.07179
# 100/100 [==============================] - 753s 8s/step - loss: 0.0695 - mean_io_u_3: 0.4810 - val_loss: 0.0748 - val_mean_io_u_3: 0.4809
# Epoch 20/20
# 100/100 [==============================] - ETA: 0s - loss: 0.0654 - mean_io_u_3: 0.4814
# Epoch 00020: val_loss improved from 0.07179 to 0.07092, saving model to ./../data/weights/UNet_TEGUCIGALPA_160x160_130_40_spe100.h5
# 100/100 [==============================] - 758s 8s/step - loss: 0.0654 - mean_io_u_3: 0.4814 - val_loss: 0.0709 - val_mean_io_u_3: 0.4830
# 3/3 [==============================] - 6s 2s/step - loss: 0.0609 - mean_io_u_3: 0.4833
# *** Final  metrics ***
# Loss: 0.06087782606482506
# Mean IoU: 0.48327311873435974

# %% [markdown]
# Graficamos las métricas generadas.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))

plt.subplot(121)
plt.plot(res_config.history['loss'])
plt.plot(res_config.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.subplot(122)
plt.plot(res_config.history['mean_io_u_3'])
plt.plot(res_config.history['val_mean_io_u_3'])
plt.title('mean_iou')
plt.ylabel('val_mean_iou')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')


plt.show()
